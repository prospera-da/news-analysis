# %% [markdown]
# # %% [markdown]
#
#  # EDA

# %%
# %%

# pip install pandas matplotlib nltk wordcloud --upgrade

# %%
# %%

import pandas as pd

df = pd.read_csv("data/news-watch-ketegangan perdagangan-sd-2024-01.csv")
df
# Out:
#                                                   title         publish_date  \
# 0     Sempat Terbang, Emas Hancur Bersama Mundurnya ...  2024-07-23 06:50:00
# 1     Breaking! Harga Emas Tembus Rekor Baru, Mepet ...  2025-02-10 14:06:00
# 2     Perdagangan Internasional: Pengertian, Manfaat...  2024-05-03 07:00:00
# 3     Serangan Israel Tidak Mempan ke Iran, Harga Mi...  2024-10-28 10:35:00
# 4     7 Fakta Pemilu AS 2024, Siapa yang Dunia Mau J...  2024-11-05 15:05:00
# ...                                                 ...                  ...
# 4436  Isi Lengkap Perang Dagang 2.0 Trump, Tarif Ber...  2025-02-03 08:55:00
# 4437  Bangga! Lewat Nikel, RI Bakal Punya Peran Stra...  2024-10-29 12:40:00
# 4438  Cegah Serbuan Produk China ke AS, Biden Mau Na...  2024-04-18 08:45:00
# 4439  Putar Otak Siasati Ancaman Perang Dagang AS-Ch...  2025-01-15 12:55:00
# 4440  Naik Whoosh Cuma Rp50 Ribu Mulai 1 November 20...  2024-11-01 16:17:00
#
#                                     author  \
# 0               Chandra Dwi,CNBC Indonesia
# 1                       mae,CNBC Indonesia
# 2          Nur Wasilatus Sholeha -detikEdu
# 3        Robertus Andrianto,CNBC Indonesia
# 4     Tommy Patrio Sorongan,CNBC Indonesia
# ...                                    ...
# 4436    Thea Fathanah Arbar,CNBC Indonesia
# 4437    Firda Dwi Muliawati,CNBC Indonesia
# 4438         Aulia Damayanti -detikFinance
# 4439       Amanda Christabel -detikFinance
# 4440          Tya Eka Yulianti -detikJabar
#
#                                                 content  \
# 0     Jakarta, CNBC Indonesia\n- Harga emas ditutup ...
# 1     Jakarta, CNBC Indonesia\n- Harga emas tembus r...
# 2     Daftar Isi\nPengertian Perdagangan Internasion...
# 3     Jakarta, CNBC Indonesia -\nHarga minyak mentah...
# 4     Jakarta, CNBC Indonesia\n-\nAmerika Serikat (A...
# ...                                                 ...
# 4436  Jakarta, CNBC Indonesia\n- Presiden Amerika Se...
# 4437  Jakarta, CNBC Indonesia -\nHolding BUMN Pertam...
# 4438  Jakarta\n-\nPresiden Amerika Serikat (AS) Joe ...
# 4439  Jakarta\n-\nPemerintah mengatakan kekhawatiran...
# 4440  Daftar Isi\nRute Baru Whoosh Padalarang-Tegall...
#
#                      keyword         category             source  \
# 0     ketegangan perdagangan  Berita Research  cnbcindonesia.com
# 1                tarif trump  Berita Research  cnbcindonesia.com
# 2               perang tarif         detikEdu          detik.com
# 3     ketegangan perdagangan    Berita Market  cnbcindonesia.com
# 4               perang tarif           Berita  cnbcindonesia.com
# ...                      ...              ...                ...
# 4436            perang tarif           Berita  cnbcindonesia.com
# 4437            perang tarif           Berita  cnbcindonesia.com
# 4438             tarif China     detikFinance          detik.com
# 4439                tarif AS     detikFinance          detik.com
# 4440             tarif China       detikJabar          detik.com
#
#                                                    link
# 0     https://www.cnbcindonesia.com/research/2024072...
# 1     https://www.cnbcindonesia.com/research/2025021...
# 2     https://www.detik.com/edu/detikedu/d-7321635/p...
# 3     https://www.cnbcindonesia.com/market/202410280...
# 4     https://www.cnbcindonesia.com/news/20241105144...
# ...                                                 ...
# 4436  https://www.cnbcindonesia.com/news/20250203075...
# 4437  https://www.cnbcindonesia.com/news/20241029121...
# 4438  https://finance.detik.com/berita-ekonomi-bisni...
# 4439  https://finance.detik.com/berita-ekonomi-bisni...
# 4440  https://www.detik.com/jabar/bisnis/d-7617609/n...
#
# [4441 rows x 8 columns]

# %%
# %%

pd.crosstab(df["keyword"], df["source"])
# Out:
# source                  bisnisindonesia.id  cnbcindonesia.com  detik.com  \
# keyword
# balas tarif                              2                 23         22
# ketegangan perdagangan                   1                459        234
# penguatan dolar                          7                 36         10
# penguatan dollar                        11                 24         29
# perang dagang                           20                 31        368
# perang tarif                            15                443        221
# tarif AS                                16                471        478
# tarif China                             20                 29        396
# tarif trump                             20                484        282
#
# source                  katadata.co.id  kompas.com  kontan.co.id  viva.co.id
# keyword
# balas tarif                          3           4             0           1
# ketegangan perdagangan               1           0             3           4
# penguatan dolar                      6           0            15           5
# penguatan dollar                     0           6             1           0
# perang dagang                       10          17            18          13
# perang tarif                         7           7            13          10
# tarif AS                            10           5            22          16
# tarif China                          0           0            20          12
# tarif trump                         10          11            23          16

# %%
# %%

df = df.drop_duplicates(subset=["keyword", "source", "link"])

excluded_cols = ["keyword", "source", "link"]
other_cols = [col for col in df.columns if col not in excluded_cols]

agg_funcs = {
    "keywords": ("keyword", lambda x: ",".join(x)),  # join all values
    "keyword": ("keyword", "first"),  # keep the first value
}
agg_funcs.update({col: (col, "first") for col in other_cols})

df = df.groupby(["source", "link"], as_index=False).agg(**agg_funcs)

df["content"] = df["content"].fillna("")
df["publish_date"] = pd.to_datetime(df["publish_date"])
df
# Out:
#                   source                                               link  \
# 0     bisnisindonesia.id  https://bisnisindonesia.id/article/aaui-usulka...
# 1     bisnisindonesia.id  https://bisnisindonesia.id/article/ambisi-ekst...
# 2     bisnisindonesia.id  https://bisnisindonesia.id/article/ancaman-bom...
# 3     bisnisindonesia.id  https://bisnisindonesia.id/article/arti-kenaik...
# 4     bisnisindonesia.id  https://bisnisindonesia.id/article/as-kerek-ta...
# ...                  ...                                                ...
# 2538          viva.co.id  https://www.viva.co.id/militer/militer-dunia/1...
# 2539          viva.co.id  https://www.viva.co.id/otomotif/1728481-barang...
# 2540          viva.co.id  https://www.viva.co.id/otomotif/1776653-harley...
# 2541          viva.co.id  https://www.viva.co.id/trending/1731333-potens...
# 2542          viva.co.id  https://www.viva.co.id/video/1796821-panas-chi...
#
#                     keywords                 keyword  \
# 0                   tarif AS                tarif AS
# 1              perang dagang           perang dagang
# 2               perang tarif            perang tarif
# 3                tarif China             tarif China
# 4                tarif China             tarif China
# ...                      ...                     ...
# 2538             tarif trump             tarif trump
# 2539             tarif China             tarif China
# 2540            perang tarif            perang tarif
# 2541  ketegangan perdagangan  ketegangan perdagangan
# 2542    tarif China,tarif AS             tarif China
#
#                                                   title        publish_date  \
# 0     AAUI Usulkan Kenaikan Tarif Premi Asuransi Gem... 2024-10-04 20:14:20
# 1     Ambisi Ekstrem Trump Kuasai Greenland, Kanada,... 2025-01-09 13:59:45
# 2         Ancaman Bom Waktu Kampanye Tarif Donald Trump 2024-11-04 23:01:07
# 3     Arti Kenaikan Tarif Impor China Bagi Indonesia... 2024-05-19 12:57:30
# 4     AS Kerek Tarif Impor Produk Energi Bersih dari... 2024-05-12 08:44:24
# ...                                                 ...                 ...
# 2538  Meksiko Kirim 10 Ribu Tentara ke Perbatasan Am... 2025-02-04 19:10:00
# 2539  Barang China Bakal Kena Bea Impor 200 Persen, ... 2024-07-02 11:34:00
# 2540       Harley-Davidson Terjepit Perang Dagang Trump 2024-11-29 11:48:00
# 2541  Potensi Tarif Kendaraan Listrik Tiongkok di Ka... 2024-07-10 21:25:00
# 2542  PANAS! China Akan Gugat AS Terkait Kenaikan Ta... 2025-02-10 13:20:00
#
#                              author  \
# 0          Asteria Desi Kartikasari
# 1                     Nindya Aldila
# 2                     Nindya Aldila
# 3                     Nindya Aldila
# 4                     Nindya Aldila
# ...                             ...
# 2538     Oleh :Radhitya Andriansyah
# 2539          Oleh :Yunisa Herawati
# 2540          Oleh :Yunisa Herawati
# 2541           Oleh :Zaky Al-Yamani
# 2542  Oleh :Tim Multimedia,Dwi Agus
#
#                                                 content  \
# 0     Bisnis, JAKARTA— Asosiasi Asuransi Umum Indone...
# 1     Bisnis, JAKARTA - Presiden Amerika Serikat ter...
# 2     Bisnis, JAKARTA - Perebutan kursi nomor satu d...
# 3     Bisnis, JAKARTA - Kenaikan tarif impor terbaru...
# 4     Bisnis, JAKARTA - Amerika Serikat bakal menamb...
# ...                                                 ...
# 2538  VIVA – Angkatan Bersenjata Meksiko dikabarkan ...
# 2539  Jakarta, 2 Juli 2024 – Indonesia dikabarkan ak...
# 2540  Milwaukee, VIVA – Perang tarif kembali menjadi...
# 2541  VIVA – Kanada mulai mengevaluasi dampak dugaan...
# 2542  VIVA - China kembali mengeluarkan pernyataan t...
#
#                       category
# 0         Finansial - Asuransi
# 1     Ekonomi - Ekonomi Global
# 2     Ekonomi - Ekonomi Global
# 3     Ekonomi - Ekonomi Global
# 4     Ekonomi - Ekonomi Global
# ...                        ...
# 2538                   Militer
# 2539                  Otomotif
# 2540                  Otomotif
# 2541                  Trending
# 2542                     Video
#
# [2543 rows x 9 columns]

# %%
# %%

pd.crosstab(df["keyword"], df["source"])
# Out:
# source                  bisnisindonesia.id  cnbcindonesia.com  detik.com  \
# keyword
# balas tarif                              2                 11         11
# ketegangan perdagangan                   1                392        184
# penguatan dolar                          2                 15          6
# penguatan dollar                         9                 20         22
# perang dagang                           12                 12        266
# perang tarif                             8                260         89
# tarif AS                                12                195        238
# tarif China                             10                  7        209
# tarif trump                              5                219        101
#
# source                  katadata.co.id  kompas.com  kontan.co.id  viva.co.id
# keyword
# balas tarif                          1           3             0           0
# ketegangan perdagangan               1           0             3           4
# penguatan dolar                      6           0            15           5
# penguatan dollar                     0           6             1           0
# perang dagang                        8          16            17           9
# perang tarif                         3           7            13           5
# tarif AS                             7           5            19           7
# tarif China                          0           0            17           7
# tarif trump                          8           8            18           6

# %%
# %%

# Trend over time
df.set_index("publish_date").resample("W").size().plot()
# Out:
# <Axes: xlabel='publish_date'>

# %%
# %%

# Trend by source
df.groupby("source").resample("W", on="publish_date").size().unstack(0).plot()
# Out:
# <Axes: xlabel='publish_date'>

# %%
# %%

# Hourly analysis
df["publish_hour"] = df["publish_date"].dt.hour
df.groupby("publish_hour").size().plot()
# Out:
# <Axes: xlabel='publish_hour'>

# %%
# %%

df["source"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='source'>

# %%
# %%

from collections import Counter

# top keywords
keywords = df["keywords"].str.split(",").explode().str.strip()
keyword_freq = Counter(keywords)
keywords_df = pd.DataFrame(keyword_freq.items(), columns=["keyword", "count"])
keywords_df.set_index("keyword", inplace=True)
keywords_df.plot(kind="barh")
# Out:
# <Axes: ylabel='keyword'>

# %%
# %%

import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from wordcloud import WordCloud

# Indonesian text preprocessing
id_stopwords = set(stopwords.words("indonesian") + ["CNBC Indonesia", "jakarta"])

# Generate word cloud
text_corpus = " ".join(df["content"])
wordcloud_news = WordCloud(stopwords=id_stopwords, background_color="white").generate(
    text_corpus
)

plt.imshow(wordcloud_news, interpolation="bilinear")
plt.axis("off")
plt.show()
