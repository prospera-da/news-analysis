# %% [markdown]
# #Basic Python Exercise

# %%
#Installing Packages needed for Exercise
# !pip install --upgrade pandas-datareader
# !pip install --upgrade yfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 1.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.52
#     Uninstalling yfinance-0.2.52:
#       Successfully uninstalled yfinance-0.2.52
# ...

# %%
#Importing Packages Used In Exercise
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# #Information of Dataset
# POP: Population (in thousands)
#
# XRAT: Exchange Rate to US Dollar
#
# tcgdp: Total PPP Converted GDP (in million international dollar)
#
# cc: Consumption Share of PPP Converted GDP Per Capita (%)
#
# cg: Government Consumption Share of PPP Converted GDP Per Capita (%)

# %%
#Importing Dataset from Github
df = pd.read_csv('https://raw.githubusercontent.com/QuantEcon/lecture-python-programming/master/source/_static/lecture_specific/pandas/data/test_pwt.csv')
df
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
#Creating Subset of Dataframe
df_subset = df[['country', 'POP', 'tcgdp']]
df_subset
# Out:
#          country          POP         tcgdp
# 0      Argentina    37335.653  2.950722e+05
# 1      Australia    19053.186  5.418047e+05
# 2          India  1006300.297  1.728144e+06
# 3         Israel     6114.570  1.292539e+05
# 4         Malawi    11801.505  5.026222e+03
# 5   South Africa    45064.098  2.272424e+05
# 6  United States   282171.957  9.898700e+06
# 7        Uruguay     3219.793  2.525596e+04

# %%
#Showing Dataset Based on Index Number (Order in Dataset)
df[2:5]
# Out:
#   country country isocode  year          POP       XRAT         tcgdp  \
# 2   India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3  Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4  Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
#
#           cc         cg
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954

# %%
#Showing Dataset Based on Variable
df[['country', 'tcgdp']]
# Out:
#          country         tcgdp
# 0      Argentina  2.950722e+05
# 1      Australia  5.418047e+05
# 2          India  1.728144e+06
# 3         Israel  1.292539e+05
# 4         Malawi  5.026222e+03
# 5   South Africa  2.272424e+05
# 6  United States  9.898700e+06
# 7        Uruguay  2.525596e+04

# %%
#Showing Dataset Based on Index Number (Order in Dataset) and Variable
df.loc[df.index[2:5], ['country', 'tcgdp']]
# Out:
#   country         tcgdp
# 2   India  1.728144e+06
# 3  Israel  1.292539e+05
# 4  Malawi  5.026222e+03

# %% [markdown]
# #Select Data by Conditions

# %%
#Showing Dataset Based on Variable Value (For Example Population)
df[df.POP >= 20000]
# Out:
#          country country isocode  year          POP      XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.99950  2.950722e+05
# 2          India             IND  2000  1006300.297  44.94160  1.728144e+06
# 5   South Africa             ZAF  2000    45064.098   6.93983  2.272424e+05
# 6  United States             USA  2000   282171.957   1.00000  9.898700e+06
#
#           cc         cg
# 0  75.716805   5.578804
# 2  64.575551  14.072206
# 5  72.718710   5.726546
# 6  72.347054   6.032454

# %%
#Showing Dataset Based on More than 1 Variable Value
df[(df.cc + df.cg >= 80) & (df.POP <= 20000)]
# Out:
#    country country isocode  year        POP       XRAT         tcgdp  \
# 4   Malawi             MWI  2000  11801.505  59.543808   5026.221784
# 7  Uruguay             URY  2000   3219.793  12.099592  25255.961693
#
#           cc         cg
# 4  74.707624  11.658954
# 7  78.978740   5.108068

# %% [markdown]
# #Analytic Tools

# %%
#Counting How Many Unique Countries in Dataset
countries = df.country.unique()
len(countries)
# Out:
# 8

# %%
#Calculating Mean Value of Data
df[['year', 'POP', 'XRAT', 'tcgdp', 'cc', 'cg']].apply(np.mean).apply(lambda x: format(x, 'f'))
# Out:
# year        2000.000000
# POP       176382.632375
# XRAT          16.415811
# tcgdp    1606312.461598
# cc            71.404995
# cg             8.145477
# dtype: object

# %%
#Calculating Maximum Value of Data
df[['year', 'POP', 'XRAT', 'tcgdp', 'cc', 'cg']].apply(min).apply(lambda x: format(x, 'f'))
# Out:
# year     2000.000000
# POP      3219.793000
# XRAT        0.999500
# tcgdp    5026.221784
# cc         64.436451
# cg          5.108068
# dtype: object

# %%
#Calculating Maximum Value of Data
df[['year', 'POP', 'XRAT', 'tcgdp', 'cc', 'cg']].apply(max).apply(lambda x: format(x, 'f'))
# Out:
# year        2000.000000
# POP      1006300.297000
# XRAT          59.543808
# tcgdp    9898700.000000
# cc            78.978740
# cg            14.072206
# dtype: object

# %%
#Creating Summary of Data (Count, Mean, Std Deviation, Min, Q1, Q2, Q3, Max)
df.describe()
# Out:
#          year           POP       XRAT         tcgdp         cc         cg
# count     8.0  8.000000e+00   8.000000  8.000000e+00   8.000000   8.000000
# mean   2000.0  1.763826e+05  16.415811  1.606312e+06  71.404995   8.145477
# std       0.0  3.479223e+05  22.758175  3.397025e+06   5.318015   3.383397
# min    2000.0  3.219793e+03   0.999500  5.026222e+03  64.436451   5.108068
# 25%    2000.0  1.037977e+04   1.543623  1.032544e+05  66.963157   5.689611
# 50%    2000.0  2.819442e+04   5.508580  2.611573e+05  72.532882   6.376276
# 75%    2000.0  1.043411e+05  20.310094  8.383896e+05  74.959919  10.614755
# max    2000.0  1.006300e+06  59.543808  9.898700e+06  78.978740  14.072206

# %% [markdown]
# #Formalizing Dataframe and Creating Graph of GDP Per Capita

# %%
#Indexing Data Using Country Name
df_subset = df_subset.set_index('country')
df_subset
# Out:
#                        POP         tcgdp
# country
# Argentina        37335.653  2.950722e+05
# Australia        19053.186  5.418047e+05
# India          1006300.297  1.728144e+06
# Israel            6114.570  1.292539e+05
# Malawi           11801.505  5.026222e+03
# South Africa     45064.098  2.272424e+05
# United States   282171.957  9.898700e+06
# Uruguay           3219.793  2.525596e+04

# %%
#Indexing Column To Readable Names
df_subset.columns = 'population', 'total GDP'
df_subset
# Out:
#                 population     total GDP
# country
# Argentina        37335.653  2.950722e+05
# Australia        19053.186  5.418047e+05
# India          1006300.297  1.728144e+06
# Israel            6114.570  1.292539e+05
# Malawi           11801.505  5.026222e+03
# South Africa     45064.098  2.272424e+05
# United States   282171.957  9.898700e+06
# Uruguay           3219.793  2.525596e+04

# %%
#Changing Population from in Thousand People to People
df_subset['population'] = df_subset['population'] * 1000
df_subset
# Out:
#                  population     total GDP
# country
# Argentina      3.733565e+07  2.950722e+05
# Australia      1.905319e+07  5.418047e+05
# India          1.006300e+09  1.728144e+06
# Israel         6.114570e+06  1.292539e+05
# Malawi         1.180150e+07  5.026222e+03
# South Africa   4.506410e+07  2.272424e+05
# United States  2.821720e+08  9.898700e+06
# Uruguay        3.219793e+06  2.525596e+04

# %%
#Changing GDP from in Million USD to USD and Creating GDP Per Capita
df_subset['GDP percap'] = df_subset['total GDP'] * 1e6 / df_subset['population']
df_subset
# Out:
#                  population     total GDP    GDP percap
# country
# United States  2.821720e+08  9.898700e+06  35080.381854
# Australia      1.905319e+07  5.418047e+05  28436.433261
# Israel         6.114570e+06  1.292539e+05  21138.672749
# Argentina      3.733565e+07  2.950722e+05   7903.229085
# Uruguay        3.219793e+06  2.525596e+04   7843.970620
# South Africa   4.506410e+07  2.272424e+05   5042.647686
# India          1.006300e+09  1.728144e+06   1717.324719
# Malawi         1.180150e+07  5.026222e+03    425.896679

# %%
#Creating GDP Per Capita Graph (NOTE: Not Based on Size Order)
ax = df_subset['GDP percap'].plot(kind='bar')
ax.set_xlabel('country', fontsize=12)
ax.set_ylabel('GDP per capita', fontsize=12)
plt.show()

# %%
#Reordering Data based GDP Per Capita Value
df_subset = df_subset.sort_values(by='GDP percap', ascending=False)
df_subset
# Out:
#                  population     total GDP    GDP percap
# country
# United States  2.821720e+08  9.898700e+06  35080.381854
# Australia      1.905319e+07  5.418047e+05  28436.433261
# Israel         6.114570e+06  1.292539e+05  21138.672749
# Argentina      3.733565e+07  2.950722e+05   7903.229085
# Uruguay        3.219793e+06  2.525596e+04   7843.970620
# South Africa   4.506410e+07  2.272424e+05   5042.647686
# India          1.006300e+09  1.728144e+06   1717.324719
# Malawi         1.180150e+07  5.026222e+03    425.896679

# %%
#Creating GDP Per Capita Graph (Better Visualization)
ax = df_subset['GDP percap'].plot(kind='bar')
ax.set_xlabel('country', fontsize=12)
ax.set_ylabel('GDP per capita', fontsize=12)
plt.show()

# %% [markdown]
# #Extracting Data From Yahoo Finance

# %%
#Importing Packages for Yahoo Finance Exercise
import datetime as dt
import yfinance as yf

# %%
#Choosing Indices to be Imported
indices_list = {'^GSPC': 'S&P 500',
               '^IXIC': 'NASDAQ',
               '^DJI': 'Dow Jones',
               '^N225': 'Nikkei'}

# %%
#Create a Function to Extract Yahoo Finance Data
def read_data(ticker_list,
          start=dt.datetime(2021, 1, 1),
          end=dt.datetime(2024, 12, 31)):
    """
    This function reads in closing price data from Yahoo
    for each tick in the ticker_list.
    """
    ticker = pd.DataFrame()

    for tick in ticker_list:
        stock = yf.Ticker(tick)
        prices = stock.history(start=start, end=end)

        # Change the index to date-only
        prices.index = pd.to_datetime(prices.index.date)

        closing_prices = prices['Close']
        ticker[tick] = closing_prices

    return ticker
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8d5fc797e68> in <cell line: 0>()
#       1 #Create a Function to Extract Yahoo Finance Data
#       2 def read_data(ticker_list,
# ----> 3           start=dt.datetime(2021, 1, 1),
#       4           end=dt.datetime(2024, 12, 31)):
#       5     """
#
# NameError: name 'dt' is not defined

# %%
#Extracting Dataset from Yahoo Finance Based on the determined Indices
indices_data = read_data(
        indices_list,
        start=dt.datetime(1971, 1, 1),  #Common Start Date
        end=dt.datetime(2024, 12, 31)
)

# %%
#Creating the Data of Yearly Returns
yearly_returns = pd.DataFrame()

for index, name in indices_list.items():
    p1 = indices_data.groupby(indices_data.index.year)[index].first()  # Get the first set of returns as a DataFrame
    p2 = indices_data.groupby(indices_data.index.year)[index].last()   # Get the last set of returns as a DataFrame
    returns = (p2 - p1) / p1
    yearly_returns[name] = returns

yearly_returns
# Out:
#        S&P 500    NASDAQ  Dow Jones    Nikkei
# 1971  0.120022  0.141200        NaN  0.364072
# 1972  0.161110  0.176683        NaN  0.920112
# 1973 -0.180940 -0.315234        NaN -0.176970
# 1974 -0.298116 -0.353507        NaN -0.099143
# 1975  0.284209  0.278748        NaN  0.167980
# 1976  0.182178  0.253907        NaN  0.133496
# 1977 -0.111215  0.075340        NaN -0.027174
# 1978  0.024408  0.134423        NaN  0.232942
# 1979  0.115890  0.282587        NaN  0.087378
# 1980  0.283661  0.365594        NaN  0.076670
# 1981 -0.101144 -0.037878        NaN  0.074240
# 1982  0.145837  0.188616        NaN  0.038585
# 1983  0.192208  0.208205        NaN  0.233428
# 1984  0.019508 -0.109966        NaN  0.162735
# 1985  0.277620  0.321269        NaN  0.133430
# 1986  0.155446  0.073231        NaN  0.441777
# 1987  0.002556 -0.064270        NaN  0.145769
# 1988  0.085098  0.126736        NaN  0.421452
# 1989  0.283644  0.201268        NaN  0.286745
# ...

# %%
#Summary Statistics of Dataset
yearly_returns.describe()
# Out:
#          S&P 500     NASDAQ  Dow Jones     Nikkei
# count  54.000000  54.000000  33.000000  54.000000
# mean    0.092349   0.131421   0.087929   0.081369
# std     0.166868   0.252664   0.138794   0.240747
# min    -0.375847  -0.401978  -0.327168  -0.396956
# 25%    -0.004557  -0.012117   0.020721  -0.071132
# 50%     0.117302   0.146170   0.093873   0.082024
# 75%     0.216574   0.281627   0.202304   0.206602
# max     0.341574   0.842943   0.333111   0.920112

# %%
#Creating Graph
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

for iter_, ax in enumerate(axes.flatten()):            # Flatten 2-D array to 1-D array
    index_name = yearly_returns.columns[iter_]         # Get index name per iteration
    ax.plot(yearly_returns[index_name])                # Plot pct change of yearly returns per index
    ax.set_ylabel("percent change", fontsize = 12)
    ax.set_title(index_name)

plt.tight_layout()
